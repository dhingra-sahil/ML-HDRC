# %%
_,num_cols,_,_ = id_num_cat_feature(train, text = False)
#datasets[ds_name].replace([np.inf, -np.inf], 0, inplace=True)

num_plot(train, num_cols, remove=['SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV'], figsize = (15,3))
